# %%
import os
import pandas as pd
import re

# %%
os.getcwd()
# Out:
# '/home/ywt01/codes/dlib_test/examples/exampleSet'

# %%
os.path.dirname(os.path.abspath(__file__))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-86-880eb789ae8a> in <module>
# ----> 1 os.path.dirname(os.path.abspath(__file__))
#
# NameError: name '__file__' is not defined

# %%
con_M=pd.read_csv('/home/ywt01/codes/dlib_test/examples/exampleSet/Confusion_matrix.csv',index_col=0)
con_M=con_M.set_index(['predict'],drop=True,append=True)
# Out:
#                    P  N
# Tolerance predict
# Tole:0.1  T        0  0
#           F        0  0
# Tole:0.2  T        0  0
#           F        0  0
# Tole:0.3  T        0  0
#           F        0  0
# Tole:0.4  T        0  0
#           F        0  0
# Tole:0.5  T        0  0
#           F        0  0
# Tole:0.6  T        0  0
#           F        0  0
# Tole:0.7  T        0  0
#           F        0  0
# Tole:0.8  T        0  0
#           F        0  0
# Tole:0.9  T        0  0
#           F        0  0
# Tole:1.0  T        0  0
#           F        0  0

# %%
con_M.loc['F']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# KeyError: 'F'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-96-384c4ed77993> in <module>
# ----> 1 con_M.loc['F']
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1422
# ...

# %%
con_M.set_index(['index2'],drop=True,append=True)
# Out:
#          Unnamed: 1  P  N
# Tole:0.1          T  0  0
# Tole:0.1          F  0  0
# Tole:0.2          T  0  0
# Tole:0.2          F  0  0
# Tole:0.3          T  0  0
# Tole:0.3          F  0  0
# Tole:0.4          T  0  0
# Tole:0.4          F  0  0
# Tole:0.5          T  0  0
# Tole:0.5          F  0  0
# Tole:0.6          T  0  0
# Tole:0.6          F  0  0
# Tole:0.7          T  0  0
# Tole:0.7          F  0  0
# Tole:0.8          T  0  0
# Tole:0.8          F  0  0
# Tole:0.9          T  0  0
# Tole:0.9          F  0  0
# Tole:1.0          T  0  0
# Tole:1.0          F  0  0

# %%
import numpy as np
import pandas as pd 
df = pd.DataFrame({
    'index1': ['A', 'A', 'A', 'A', 'B', 'B', 'B', 'B'],
    'index2': [1, 2, 3, 4, 1, 2, 3, 4],
    'column1': np.random.randint(2, size=8),
    'column2': np.random.randint(2, size=8),
    'column3': np.random.randint(2, size=8)
}).set_index(['index1', 'index2'])

df
# Out:
#                column1  column2  column3
# index1 index2
# A      1             0        0        0
#        2             0        1        0
#        3             0        1        1
#        4             1        0        0
# B      1             0        0        0
#        2             1        0        1
#        3             1        1        0
#        4             1        1        1

# %%
df.to_csv('mycsv.csv')

# %%
df_r=pd.read_csv('/home/ywt01/codes/dlib_test/examples/exampleSet/mycsv.csv',index_col=0)
df_r
df_r.set_index(['index2'],drop=True,append=True)
# Out:
#                column1  column2  column3
# index1 index2
# A      1             1        0        0
#        2             0        0        0
#        3             0        0        0
#        4             0        1        1
# B      1             0        0        0
#        2             0        1        0
#        3             0        0        0
#        4             0        1        0
