# %%
import os
import pandas as pd
import re

# %%
label = pd.read_csv('testSetTable.csv')
label = label.loc[label['filename']=='ford003.jpg',:]
for key in label.columns[2:6]:
    print(label[key].values.item(0))
# Out:
# 0
# 0
# 1
# 0

# %%
import numpy as np 
x = np.random.randint(9, size=(3, 3))
x
# Out:
# array([[8, 2, 1],
#        [1, 6, 2],
#        [0, 2, 0]])

# %%
x.item((1,1))
# Out:
# 6

# %%
test_photo_property.loc[:,'filename']
# Out:
# 0             ford001.jpg
# 1             ford002.jpg
# 2             ford003.jpg
# 3             ford004.jpg
# 4             ford005.jpg
# 5             ford006.jpg
# 6             ford007.jpg
# 7              hao001.jpg
# 8              hao002.jpg
# 9              hao003.jpg
# 10             hao004.jpg
# 11             hao005.jpg
# 12             hao006.jpg
# 13             hao007.jpg
# 14             hao008.jpg
# 15             hao009.jpg
# 16             ywt001.png
# 17             ywt002.png
# 18             ywt003.png
# 19             ywt004.png
# 20             ywt005.png
# 21             ywt006.png
# 22             ywt007.png
# 23             ywt008.png
# 24             ywt009.png
# 25             ywt010.jpg
# 26             ywt011.jpg
# 27             ywt012.jpg
# 28             ywt013.jpg
# 29             ywt014.jpg
# 30             ywt015.jpg
# 31             ywt016.jpg
# 32             ywt017.jpg
# 33             ywt018.jpg
# 34             ywt019.jpg
# 35    ywt_hao_ford001.jpg
# 36    ywt_hao_ford002.jpg
# Name: filename, dtype: object

# %%
test_photo_property.loc[test_photo_property['filename'].str.match(r"\w+ford|ford"),'ford']=1
test_photo_property.loc[test_photo_property['filename'].str.match(r"\w+hao|hao"),'hao']=1
test_photo_property.loc[test_photo_property['filename'].str.match(r"\w+ywt|ywt"),'ywt']=1
test_photo_property
# Out:
#                filename  ywt  hao  ford  unknown  DOD
# 0           ford001.jpg    0    0     1        0    0
# 1           ford002.jpg    0    0     1        0    0
# 2           ford003.jpg    0    0     1        0    0
# 3           ford004.jpg    0    0     1        0    0
# 4           ford005.jpg    0    0     1        0    0
# 5           ford006.jpg    0    0     1        0    0
# 6           ford007.jpg    0    0     1        0    0
# 7            hao001.jpg    0    1     0        0    0
# 8            hao002.jpg    0    1     0        0    0
# 9            hao003.jpg    0    1     0        0    0
# 10           hao004.jpg    0    1     0        0    0
# 11           hao005.jpg    0    1     0        0    0
# 12           hao006.jpg    0    1     0        0    0
# 13           hao007.jpg    0    1     0        0    0
# 14           hao008.jpg    0    1     0        0    0
# 15           hao009.jpg    0    1     0        0    0
# 16           ywt001.png    1    0     0        0    0
# 17           ywt002.png    1    0     0        0    0
# 18           ywt003.png    1    0     0        0    0
# 19           ywt004.png    1    0     0        0    0
# 20           ywt005.png    1    0     0        0    0
# 21           ywt006.png    1    0     0        0    0
# 22           ywt007.png    1    0     0        0    0
# 23           ywt008.png    1    0     0        0    0
# 24           ywt009.png    1    0     0        0    0
# 25           ywt010.jpg    1    0     0        0    0
# 26           ywt011.jpg    1    0     0        0    0
# 27           ywt012.jpg    1    0     0        0    0
# 28           ywt013.jpg    1    0     0        0    0
# 29           ywt014.jpg    1    0     0        0    0
# 30           ywt015.jpg    1    0     0        0    0
# 31           ywt016.jpg    1    0     0        0    0
# 32           ywt017.jpg    1    0     0        0    0
# 33           ywt018.jpg    1    0     0        0    0
# 34           ywt019.jpg    1    0     0        0    0
# 35  ywt_hao_ford001.jpg    1    1     1        0    0
# 36  ywt_hao_ford002.jpg    1    1     1        0    0

# %%
os.getcwd()
# Out:
# '/home/ywt01/codes/dlib_test/examples/exampleSet'

# %%
import os
import pandas as pd
import re
import logging 
import sys

logging.basicConfig(level=logging.DEBUG)
logging.debug(sys.path[0]+'\n')
logging.debug(os.listdir(sys.path[0]+'/photo'))
data=[{'filename':f'{filename}','ywt':0,'hao':0,'ford':0,'unknown':0,'DOD':0} for filename in sorted(os.listdir(sys.path[0]+'/photo'))]
test_photo_property = pd.DataFrame(data)
test_photo_property.loc[test_photo_property['filename'].str.match(r"\w+ford|ford"),'ford']=1
test_photo_property.loc[test_photo_property['filename'].str.match(r"\w+hao|hao"),'hao']=1
test_photo_property.loc[test_photo_property['filename'].str.match(r"\w+ywt|ywt"),'ywt']=1
logging.debug(os.getcwd())
test_photo_property.to_csv(sys.path[0]+'/testSetTable.csv')
# Out:
# DEBUG:root:/usr/lib/python36.zip
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-73-8b056474828d> in <module>
#       7 logging.basicConfig(level=logging.DEBUG)
#       8 logging.debug(sys.path[0]+'\n')
# ----> 9 logging.debug(os.listdir(sys.path[0]+'/photo'))
#      10 data=[{'filename':f'{filename}','ywt':0,'hao':0,'ford':0,'unknown':0,'DOD':0} for filename in sorted(os.listdir(sys.path[0]+'/photo'))]
#      11 test_photo_property = pd.DataFrame(data)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/usr/lib/python36.zip/photo'

# %%
os.path
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-72-74a7c4098921> in <module>
# ----> 1 os.path()
#
# TypeError: 'module' object is not callable
